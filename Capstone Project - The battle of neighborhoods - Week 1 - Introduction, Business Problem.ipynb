# %% [markdown]
# # Covid-19 cases in City of Toronto neighborhoods

# %% [markdown]
# ## Data

# %% [markdown]
# To study the number of covid-19 cases in Toronto at neighborhood level, covid-19 neighborhood data made available via City of Toronto municipality [this link](https://www.toronto.ca/home/covid-19/covid-19-latest-city-of-toronto-news/covid-19-status-of-cases-in-toronto/) is used here. The coordinates of each neighborhood are obtained from Nominatim geolocation service through GeoPy library in Python [this link](https://geopy.readthedocs.io/en/stable/). Moreover, Toronto neighborhoods population data is extracted from Wellbeing Toronto application [this link](https://map.toronto.ca/wellbeing/) to see if there is a relationship between the number of covid-19 cases in each neighborhood with population, level of income and age. Finally, `Foursquare` venues data are used to see what type of venues are most popular in the neighborhood with highest numbers of covid-19 cases. See Tables 1 to 5 in the following.

# %%
import pandas as pd
import numpy as np
import requests
#import lxml.html as lh
from pypostalcode import PostalCodeDatabase
#import re
#from operator import itemgetter
import geocoder
#import wget
from geopy.geocoders import Nominatim
import folium
from sklearn.cluster import KMeans # import k-means from clustering stage
import matplotlib.cm as cm
import matplotlib.colors as colors
import json
#import geojson
import matplotlib.pyplot as plt
import seaborn as sns
import folium.plugins
from folium.plugins import MarkerCluster
folium.plugins.MarkerCluster()
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The number of covid-19 cases in each neighborhood as of July, 14th 2020 is presented in dataframe `df_covid` below.

# %%
path_covid = '~\CityofToronto_COVID-19_NeighbourhoodData.csv'

# %% [markdown]
# #### Table 1

# %%
df_covid = pd.read_csv(path_covid)
df_covid.iloc[0:140,:].sort_values(by = 'Case Count', ascending = False).head(10)
# Out:
#      Neighbourhood ID                 Neighbourhood Name  Case Count  \
# 78                NaN        Missing Address/Postal Code         613
# 45               25.0             Glenfield-Jane Heights         499
# 125               1.0             West Humber-Clairville         471
# 82                2.0  Mount Olive-Silverstone-Jamestown         471
# 33               26.0               Downsview-Roding-CFB         443
# 139              27.0            York University Heights         420
# 58               14.0         Islington-City Centre West         351
# 127             113.0                             Weston         318
# 106             131.0                              Rouge         303
# 13               24.0                        Black Creek         299
#
#      Rate per 100,000 people
# 78                       NaN
# 45               1636.548490
# 125              1413.904899
# 82               1429.265036
# 33               1263.836586
# 139              1522.125177
# 58                798.362334
# 127              1767.452201
# 106               651.668961
# 13               1375.534802

# %% [markdown]
# - Acquiring the geolocation of neighborhoods using `Nominatim` geolocation service.

# %%
address = []
location = []
latitude = []
longitude = []
count = 0
for i in range(len(df_covid)-2):
    try:
        address = df_covid['Neighbourhood Name'][i]+', Toronto, Ontario, Canada'
        geolocator = Nominatim(user_agent="foursquare_agent")
        location = geolocator.geocode(address, timeout=10)
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    except AttributeError:
        try:
            address = address.replace(', Toronto, Ontario, Canada','').split('-')[0]+', Toronto, Ontario, Canada'
            geolocator = Nominatim(user_agent="foursquare_agent")
            location = geolocator.geocode(address, timeout=10)
            latitude.append(location.latitude)
            longitude.append(location.longitude)
        except AttributeError:
            try:
                print(address)
                address = df_covid['Neighbourhood Name'][i]+', Toronto, Ontario, Canada'
                print(address)
                address = address.replace(', Toronto, Ontario, Canada','').split('-')[1]+', Toronto, Ontario, Canada'
                print(address)
                geolocator = Nominatim(user_agent="foursquare_agent")
                location = geolocator.geocode(address, timeout=10)
                latitude.append(location.latitude)
                longitude.append(location.longitude)
            except IndexError:
                latitude.append('NaN')
                longitude.append('NaN')
        
    count += 1
    print(count, latitude[i], longitude[i])
# Out:
# 1 43.8080383 -79.2664391
# 2 43.7853531 -79.2785494
# 3 43.6017173 -79.5452325
# 4 43.6703377 -79.407117
# 5 43.7348039 -79.3572426
# 6 43.76389295 -79.45636693710946
# 7 43.6673421 -79.3884571
# 8 43.7691966 -79.3766617
# 9 43.7981268 -79.3829726
# 10 43.7373876 -79.4109253
# 11 43.6950296 -79.4716835
# 12 43.7535196 -79.2553355
# Birchcliffe, Toronto, Ontario, Canada
# Birchcliffe-Cliffside, Toronto, Ontario, Canada
# Cliffside, Toronto, Ontario, Canada
# 13 43.7111699 -79.2481769
# 14 43.6954005 -79.485495
# 15 43.781769 -79.4237615
# 16 43.70304535 -79.45134360044906
# 17 43.7381512 -79.3725113
# 18 43.6839242 -79.3569642
# 19 43.7007782 -79.4945217
# 20 43.6644734 -79.3669861
# 21 43.6867527 -79.4595746
# 22 43.6781015 -79.409415775
# 23 43.7874914 -79.1507681
# 24 43.6799189 -79.3886888
# 25 43.7088231 -79.2959856
# 26 43.7431757 -79.4517261
# 27 43.7218363 -79.2362138
# 28 43.677954 -79.4430828
# 29 43.6864333 -79.3003555
# 30 43.6864333 -79.3003555
# 31 43.7926732 -79.3547219
# 32 43.7528467 -79.282067
# 33 43.6653069 -79.4326362
# 34 43.7492988 -79.462248
# 35 43.6536319 -79.4264389
# 36 43.6684402 -79.33067
# 37 43.6722234 -79.5146852
# 38 43.7394646 -79.2320997
# 39 43.7108139 -79.5653902
# 40 43.7142417 -79.4370715
# 41 43.6622732 -79.5765162
# 42 43.6435491 -79.56532534553605
# 43 43.7184315 -79.333204
# 44 43.6935586 -79.4139023
# 45 43.6935586 -79.4139023
# 46 43.6534817 -79.3839347
# 47 43.6826052 -79.3303004
# 48 43.7552251 -79.1982293
# 49 43.7695089 -79.354296
# 50 43.6573833 -79.470961
# 51 43.64494 -79.478313
# 52 43.7901172 -79.1733344
# 53 43.6816953 -79.4257118
# 54 43.686072100000004 -79.5288038497315
# 55 43.7600778 -79.5717598
# Humbermede, Toronto, Ontario, Canada
# Humbermede, Toronto, Ontario, Canada
# 56 NaN NaN
# 57 43.6857205 -79.4251158
# 58 43.7359904 -79.2765146
# 59 43.6487953 -79.5490002
# 60 43.6654775 -79.470352
# 61 43.6901578 -79.4749985
# 62 43.724878 -79.2539688
# 63 43.6534465 -79.4002002
# 64 43.6995391 -79.5563459
# 65 43.6473811 -79.5113328
# Lambton Baby Point, Toronto, Ontario, Canada
# Lambton Baby Point, Toronto, Ontario, Canada
# 66 NaN NaN
# 67 43.799003 -79.3059669
# 68 43.7589503 -79.4225555
# 69 43.729199 -79.4032525
# 70 43.729199 -79.4032525
# 71 43.70413035 -79.37431624107815
# 72 43.64741325 -79.43111632546047
# 73 43.59200455 -79.54536450659592
# 74 43.8091955 -79.2217008
# 75 43.7122767 -79.4901977
# 76 43.63123865 -79.58543401986114
# 77 43.8231743 -79.3017626
# Mimico (includes Humber Bay Shores), Toronto, Ontario, Canada
# Mimico (includes Humber Bay Shores), Toronto, Ontario, Canada
# 78 NaN NaN
# Missing Address/Postal Code, Toronto, Ontario, Canada
# Missing Address/Postal Code, Toronto, Ontario, Canada
# 79 NaN NaN
# 80 43.7826012 -79.2049579
# 81 43.6546438 -79.3697278
# 82 43.6869597 -79.4895513
# 83 43.6534817 -79.3839347
# 84 43.7084166 -79.3901348
# 85 43.7084166 -79.3901348
# 86 43.6007625 -79.505264
# 87 43.7938863 -79.42567902301055
# 88 43.7938863 -79.42567902301055
# 89 43.6440753 -79.4086982
# 90 43.6654704 -79.3525936
# 91 43.6694032 -79.3727041
# 92 43.6971738 -79.2748232
# 93 43.6827255 -79.4380548
# 94 43.7078416 -79.3110743
# 95 43.699971000000005 -79.33251996261595
# 96 43.6600648 -79.4118056
# 97 43.7587999 -79.3201966
# 98 43.7121949 -79.51755639837398
# Playter Estates, Toronto, Ontario, Canada
# Playter Estates-Danforth, Toronto, Ontario, Canada
# Danforth, Toronto, Ontario, Canada
# 99 43.6864333 -79.3003555
# 100 43.787048 -79.3337137
# 101 43.6404664 -79.3912237
# 102 43.6607056 -79.3604569
# 103 43.7213619 -79.5655129
# 104 43.6721504 -79.4873608
# 105 43.6514426 -79.4510381
# 106 43.6903876 -79.3832965
# 107 43.8049304 -79.1658374
# 108 43.6517026 -79.4759978
# 109 43.71336615 -79.50450373904313
# 110 43.7437422 -79.2116324
# 111 43.6404954 -79.4368965
# 112 43.6654704 -79.3525936
# 113 43.6477917 -79.3848711
# 114 43.8161778 -79.3145378
# 115 43.616019449999996 -79.52700544999999
# 116 43.7792521 -79.3076282
# 117 43.6976474 -79.3011926
# 118 43.6710244 -79.296712
# 119 43.7372656 -79.5653169
# 120 43.704553 -79.3454074
# 121 43.64756465 -79.41388090266673
# 122 43.72824305 -79.37750288670469
# 123 43.732658 -79.3111892
# Waterfront Communities, Toronto, Ontario, Canada
# Waterfront Communities-The Island, Toronto, Ontario, Canada
# The Island, Toronto, Ontario, Canada
# 124 43.6534817 -79.3839347
# 125 43.7689144 -79.1872905
# 126 43.6824111 -79.4808458
# 127 43.7794959 -79.4551002
# 128 43.7001608 -79.5162474
# 129 43.7001608 -79.5162474
# Wexford/Maryvale, Toronto, Ontario, Canada
# Wexford/Maryvale, Toronto, Ontario, Canada
# 130 NaN NaN
# 131 43.7615095 -79.4109234
# 132 43.7615095 -79.4109234
# 133 43.6755594 -79.56989551321828
# 134 43.7598243 -79.2252908
# Woodbine Corridor, Toronto, Ontario, Canada
# Woodbine Corridor, Toronto, Ontario, Canada
# 135 NaN NaN
# 136 43.6865254 -79.3128596
# 137 43.682121699999996 -79.42383883756801
# 138 43.7067479 -79.3983271
# 139 43.6880189 -79.3945708

# %%
latitude.append('NaN')
latitude.append('NaN')
longitude.append('NaN')
longitude.append('NaN')

# %%
df_covid['Latitude'] = latitude
df_covid['Longitude'] = longitude

# %% [markdown]
# #### Table 2

# %%
df_covid.iloc[0:140,:].sort_values(by = 'Case Count', ascending = False).head(10)
# Out:
#      Neighbourhood ID                 Neighbourhood Name  Case Count  \
# 78                NaN        Missing Address/Postal Code         613
# 45               25.0             Glenfield-Jane Heights         499
# 125               1.0             West Humber-Clairville         471
# 82                2.0  Mount Olive-Silverstone-Jamestown         471
# 33               26.0               Downsview-Roding-CFB         443
# 139              27.0            York University Heights         420
# 58               14.0         Islington-City Centre West         351
# 127             113.0                             Weston         318
# 106             131.0                              Rouge         303
# 13               24.0                        Black Creek         299
#
#      Rate per 100,000 people Latitude Longitude
# 78                       NaN      NaN       NaN
# 45               1636.548490  43.6535  -79.3839
# 125              1413.904899  43.6824  -79.4808
# 82               1429.265036  43.6535  -79.3839
# 33               1263.836586  43.7493  -79.4622
# 139              1522.125177      NaN       NaN
# 58                798.362334  43.6488   -79.549
# 127              1767.452201  43.7002  -79.5162
# 106               651.668961  43.8049  -79.1658
# 13               1375.534802  43.6954  -79.4855

# %% [markdown]
# - Obtaining the geolocation of City of Toronto:

# %%
address0 = 'City of Toronto, ON'
geolocator0 = Nominatim(user_agent="to_explorer")
location0 = geolocator.geocode(address0)
latitude0 = location0.latitude
longitude0 = location0.longitude
print('The geograpical coordinate of City of Toronto are {}, {}.'.format(latitude0, longitude0))
# Out:
# The geograpical coordinate of City of Toronto are 43.7170226, -79.41978303501344.

# %% [markdown]
# - Cleaning the `df_covid` dataframe:

# %%
indx_rm = np.where(df_covid['Latitude'] == 'NaN')[0].tolist()

# %%
df_covid.drop(df_covid.index[indx_rm], inplace = True)

# %%
df_covid.reset_index(inplace = True)

# %%
df_covid.drop(columns = 'index', inplace = True)

# %% [markdown]
# #### Figure 1

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude0, longitude0], zoom_start=11)

# add markers to map
for lat, lng, neighborhood, case in zip(df_covid['Latitude'], df_covid['Longitude'], df_covid['Neighbourhood Name'], df_covid['Case Count']):
    label = '{}, {} cases'.format(neighborhood, case)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map of Toronto using latitude and longitude values
map_toronto2 = folium.Map(location=[latitude0, longitude0], zoom_start=10)

marker_cluster = MarkerCluster().add_to(map_toronto2)

# add markers to map
for lat, lng, neighborhood, case in zip(df_covid['Latitude'], df_covid['Longitude'], df_covid['Neighbourhood Name'], df_covid['Case Count']):
    label = '{}, {} cases'.format(neighborhood, case)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(marker_cluster)  
    
map_toronto2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Let's check the neighbourhoods with highest number of cases

# %%
df_covid.sort_values(by = 'Case Count', ascending = False).head(10)
# Out:
#      Neighbourhood ID                 Neighbourhood Name  Case Count  \
# 45               25.0             Glenfield-Jane Heights         499
# 121               1.0             West Humber-Clairville         471
# 78                2.0  Mount Olive-Silverstone-Jamestown         471
# 33               26.0               Downsview-Roding-CFB         443
# 57               14.0         Islington-City Centre West         351
# 123             113.0                             Weston         318
# 102             131.0                              Rouge         303
# 13               24.0                        Black Creek         299
# 128             137.0                             Woburn         298
# 62                6.0      Kingsview Village-The Westway         267
#
#      Rate per 100,000 people Latitude Longitude
# 45               1636.548490  43.6535  -79.3839
# 121              1413.904899  43.6824  -79.4808
# 78               1429.265036  43.6535  -79.3839
# 33               1263.836586  43.7493  -79.4622
# 57                798.362334  43.6488   -79.549
# 123              1767.452201  43.7002  -79.5162
# 102               651.668961  43.8049  -79.1658
# 13               1375.534802  43.6954  -79.4855
# 128               557.165560  43.7598  -79.2253
# 62               1213.636364  43.6995  -79.5563

# %% [markdown]
# - The data shows `Glenfield-Jane Heights`, `Mount Olive-Silverstone-Jamestown`, `West Humber-Clairville`, `Downsview-Roding-CFB` and `York University Heights` are the Toronto neighbourhoods with highest number of  covid-19 cases as of July 5th, 2020.

# %% [markdown]
# ### Age distribution of cases

# %% [markdown]
# Data is acquired from [COVID-19: Status of Cases in Toronto](https://www.toronto.ca/home/covid-19/covid-19-latest-city-of-toronto-news/covid-19-status-of-cases-in-toronto/).

# %% [markdown]
# #### Table 3

# %%
df_age = pd.read_csv('case_by_age.csv')
df_age['Age Group'][0] = '0-19'
df_age
# Out:
#   Age Group  % of Total Case Count  Case Count
# 0      0-19               6.122038         912
# 1     20-29              14.298181        2130
# 2     30-39              14.063234        2095
# 3     40-49              14.076660        2097
# 4     50-59              15.808552        2355
# 5     60-69              10.706854        1595
# 6     70-79               7.068537        1053
# 7     80-89              10.263812        1529
# 8       90+               7.377324        1099
# 9   Unknown               0.214808          32

# %% [markdown]
# We'll assume that this distribution is similar over all neighborhoods in Toronto.

# %% [markdown]
# ### Severity of cases by age

# %% [markdown]
# Data is acquired from [COVID-19: Status of Cases in Toronto](https://www.toronto.ca/home/covid-19/covid-19-latest-city-of-toronto-news/covid-19-status-of-cases-in-toronto/).

# %% [markdown]
# #### Table 4

# %%
df_severity = pd.read_csv('severity_by_age.csv')
df_severity['Age Group'][0] = '0-19'
df_severity
# Out:
#   Age Group  ICU Cases  Deaths  Hospitalized Cases  Intubated Cases
# 0      0-19          3       1                  13                1
# 1     20-29         11       1                  51                7
# 2     30-39         12       1                  85                7
# 3     40-49         40       9                 147               24
# 4     50-59         96      34                 301               77
# 5     60-69        109     102                 337               80
# 6     70-79         86     208                 355               63
# 7     80-89         39     398                 383               27
# 8       90+          4     366                 174                1
# 9   Unknown          0       0                   0                0

# %% [markdown]
# ### Well being Toronto demographics data

# %% [markdown]
# - Let's add the data from **Wellbeing Toronto** to see if we could find a relation between number of cases and demographic properties of each neighbourhood.

# %%
df_wellbeing = pd.read_csv('wellbeing_toronto.csv')

# %%
df_wellbeing.drop(columns = ['Combined Indicators'], inplace = True)

# %% [markdown]
# #### Table 5

# %%
df_wellbeing.head(10)
# Out:
#                        Neighbourhood  Neighbourhood Id  Low Income Families  \
# 0             West Humber-Clairville                 1                 3790
# 1  Mount Olive-Silverstone-Jamestown                 2                 5010
# 2       Thistletown-Beaumond Heights                 3                 1080
# 3                    Rexdale-Kipling                 4                 1110
# 4                   Elms-Old Rexdale                 5                 1190
# 5      Kingsview Village-The Westway                 6                 2800
# 6   Willowridge-Martingrove-Richview                 7                 1610
# 7           Humber Heights-Westmount                 8                  820
# 8           Edenbridge-Humber Valley                 9                  900
# 9                 Princess-Rosethorn                10                  460
#
#    Healthy Food Index  Total Area  Total Population  Pop 0 - 4 years  \
# 0               23.82       30.09             33312             1540
# 1               37.57        4.60             32954             2190
# 2               42.26        3.40             10360              540
# 3               23.31        2.50             10529              560
# 4               24.71        2.90              9456              540
# 5               35.69        5.10             22000             1425
# 6               30.46        5.50             22156             1175
# 7               32.82        2.80             10948              440
# 8               46.41        5.50             15535              565
# 9               39.52        5.20             11051              450
#
#    Pop 5 - 9 years  Pop 10 - 14 years  Pop 15 - 19 years  ...  \
# 0             1720               1790               2325  ...
# 1             2500               2415               2585  ...
# 2              600                595                650  ...
# 3              515                565                635  ...
# 4              605                660                690  ...
# 5             1485               1325               1500  ...
# 6             1230               1155               1275  ...
# 7              490                515                525  ...
# 8              705                845                885  ...
# 9              585                730                780  ...
#
#    Pop 55 - 59 years  Pop 60 - 64 years  Pop 65 - 69 years  Pop 70 - 74 years  \
# 0               2195               1795               1595               1185
# 1               1955               1520               1285                885
# 2                660                535                490                375
# 3                870                650                520                350
# 4                730                525                415                305
# 5               1330               1220               1015                750
# 6               1600               1305               1245                945
# 7                790                720                580                485
# 8               1230               1155                910                635
# 9               1045                810                630                435
#
#    Pop 75 - 79 years  Pop 80 - 84 years  Pop 85 - 89 years  Pop 90 - 94 years  \
# 0                885                700                615                160
# 1                630                465                300                 70
# 2                335                320                350                100
# 3                295                270                300                 85
# 4                235                180                145                 40
# 5                660                595                575                170
# 6                920                910                885                240
# 7                495                530                950                375
# 8                550                520                665                200
# 9                335                315                325                115
#
#    Pop 95 - 99 years  Pop 100 years and over
# 0                 50                       5
# 1                 10                       0
# 2                 20                       5
# 3                 15                       0
# 4                  5                       0
# 5                 20                       0
# 6                 30                      10
# 7                 70                      15
# 8                 55                       0
# 9                 10                       0
#
# [10 rows x 27 columns]

# %%
df_wellbeing.sort_values(by = 'Total Population', ascending = False)
# Out:
#                          Neighbourhood  Neighbourhood Id  Low Income Families  \
# 76   Waterfront Communities-The Island                77                 4480
# 136                             Woburn               137                 6860
# 50                     Willowdale East                51                 6260
# 130                              Rouge               131                 3760
# 116                         L'Amoreaux               117                 5840
# 13          Islington-City Centre West                14                 6140
# 131                            Malvern               132                 5170
# 92   Dovercourt-Wallace Emerson-Juncti                93                 3860
# 25                Downsview-Roding-CFB                26                 4060
# 44                   Parkwoods-Donalda                45                 3370
# 16                              Mimico                17                 2720
# 0               West Humber-Clairville                 1                 3790
# 1    Mount Olive-Silverstone-Jamestown                 2                 5010
# 74               Church-Yonge Corridor                75                 3860
# 81                             Niagara                82                 1730
# 94                               Annex                95                 3110
# 24              Glenfield-Jane Heights                25                 4420
# 126                            Bendale               127                 3170
# 103                Mount Pleasant West               104                 3220
# 128                    Agincourt North               129                 3980
# 118                   Wexford/Maryvale               119                 2670
# 69                     South Riverdale                70                 3060
# 41                   Banbury-Don Mills                42                 2000
# 26             York University Heights                27                 4490
# 117             Tam O'Shanter-Sullivan               118                 3100
# 135                          West Hill               136                 3710
# 46                  Don Valley Village                47                 3430
# 119                Clairlea-Birchmount               120                 2680
# 129                           Milliken               130                 3960
# 34                 Westminster-Branson                35                 3500
# ..                                 ...               ...                  ...
# 56                     Broadview North                57                 1250
# 17                         New Toronto                18                 1430
# 90                  Weston-Pellam Park                91                 1530
# 109           Keelesdale-Eglinton West               110                 1080
# 9                   Princess-Rosethorn                10                  460
# 95                           Casa Loma                96                  630
# 7             Humber Heights-Westmount                 8                  820
# 71                         Regent Park                72                 2360
# 100                  Forest Hill South               101                  550
# 22                Pelmo Park-Humberlea                23                  710
# 11                       Markland Wood                12                  510
# 3                      Rexdale-Kipling                 4                 1110
# 2         Thistletown-Beaumond Heights                 3                 1080
# 28                          Maple Leaf                29                  880
# 18                         Long Branch                19                  940
# 88        Runnymede-Bloor West Village                89                  410
# 108                 Caledonia-Fairbank               109                  930
# 27                              Rustic                28                 1340
# 139                          Guildwood               140                  440
# 65                            Danforth                66                  840
# 4                     Elms-Old Rexdale                 5                 1190
# 14                      Kingsway South                15                  260
# 40   Bridle Path-Sunnybrook-York Mills                41                  460
# 57                       Old East York                58                  630
# 113                 Lambton Baby Point               114                  690
# 59                    Woodbine-Lumsden                60                  660
# 66            Playter Estates-Danforth                67                  570
# 68                         Blake-Jones                69                  990
# 78                          University                79                 1180
# 111            Beechborough-Greenbrook               112                  950
#
#      Healthy Food Index  Total Area  Total Population  Pop 0 - 4 years  \
# 76                31.61        7.60             65913             2135
# 136               27.73       12.20             53485             3140
# 50                28.90        5.00             50434             2290
# 130               21.95       37.60             46496             2370
# 116               30.73        7.10             43993             2035
# 13                31.01       16.40             43965             2225
# 131               38.63        8.90             43794             2405
# 92                35.06        3.70             36625             1740
# 25                23.72       14.90             35052             2010
# 44                33.60        7.50             34805             1800
# 16                21.59        6.90             33964             1475
# 0                 23.82       30.09             33312             1540
# 1                 37.57        4.60             32954             2190
# 74                33.50        1.40             31340              675
# 81                34.94        3.10             31180             1190
# 94                38.85        2.80             30526              925
# 24                41.05        5.20             30491             1755
# 126               29.12        7.40             29960             1530
# 103               41.60        1.30             29658             1070
# 128               38.09        7.30             29113             1280
# 118               42.08       10.20             27917             1335
# 69                45.86        9.60             27876             1705
# 41                21.31       10.00             27695             1075
# 26                47.00       13.20             27593             1435
# 117               41.37        5.50             27446             1305
# 135               28.06        9.60             27392             1425
# 46                37.87        4.10             27051             1380
# 119               30.80        7.40             26984             1580
# 129               25.25        9.40             26572             1385
# 34                24.63        3.70             26274             1265
# ..                  ...         ...               ...              ...
# 56                31.36        1.70             11499              555
# 17                24.84        3.50             11463              620
# 90                52.57        1.50             11098              560
# 109               34.48        1.70             11058              525
# 9                 39.52        5.20             11051              450
# 95                32.33        1.90             10968              355
# 7                 32.82        2.80             10948              440
# 71                42.52        0.60             10803              530
# 100               18.49        2.50             10732              360
# 22                21.71        4.20             10722              555
# 11                 7.99        2.90             10554              350
# 3                 23.31        2.50             10529              560
# 2                 42.26        3.40             10360              540
# 28                14.42        2.50             10111              485
# 18                28.08        2.30             10084              505
# 88                45.64        1.60             10070              745
# 108               53.48        1.50              9955              505
# 27                16.55        2.10              9941              620
# 139               15.57        3.80              9917              410
# 65                32.16        1.10              9666              630
# 4                 24.71        2.90              9456              540
# 14                43.15        2.60              9271              430
# 40                22.26        8.80              9266              345
# 57                24.76        2.30              9233              465
# 113               27.28        1.70              7985              545
# 59                27.87        1.20              7865              460
# 66                42.51        0.90              7804              375
# 68                39.98        0.90              7727              520
# 78                42.62        1.40              7607              215
# 111               25.57        1.80              6577              375
#
#      Pop 5 - 9 years  Pop 10 - 14 years  Pop 15 - 19 years  ...  \
# 76               925                605               1140  ...
# 136             3365               3125               3400  ...
# 50              1930               1710               2680  ...
# 130             2810               2775               3265  ...
# 116             2045               2050               2625  ...
# 13              1930               1705               1920  ...
# 131             2680               2815               3170  ...
# 92              1480               1260               1405  ...
# 25              1870               1865               2025  ...
# 44              1980               2055               2295  ...
# 16              1090                930               1025  ...
# 0               1720               1790               2325  ...
# 1               2500               2415               2585  ...
# 74               325                270               1040  ...
# 81               510                340                385  ...
# 94               760                675               1015  ...
# 24              2010               2015               2235  ...
# 126             1495               1530               1845  ...
# 103              725                595                815  ...
# 128             1300               1240               1705  ...
# 118             1450               1420               1670  ...
# 69              1325                925               1010  ...
# 41              1260               1285               1370  ...
# 26              1350               1260               1750  ...
# 117             1335               1225               1495  ...
# 135             1590               1630               1965  ...
# 46              1420               1275               1405  ...
# 119             1490               1485               1710  ...
# 129             1260               1030               1380  ...
# 34              1110               1070               1510  ...
# ..               ...                ...                ...  ...
# 56               475                440                445  ...
# 17               570                425                545  ...
# 90               560                560                630  ...
# 109              560                525                665  ...
# 9                585                730                780  ...
# 95               400                445                445  ...
# 7                490                515                525  ...
# 71               520                590                740  ...
# 100              445                560                640  ...
# 22               610                580                675  ...
# 11               455                535                585  ...
# 3                515                565                635  ...
# 2                600                595                650  ...
# 28               520                485                605  ...
# 18               450                380                430  ...
# 88               710                595                480  ...
# 108              500                490                545  ...
# 27               660                655                730  ...
# 139              425                455                540  ...
# 65               585                455                405  ...
# 4                605                660                690  ...
# 14               550                600                595  ...
# 40               480                630                750  ...
# 57               520                490                445  ...
# 113              620                535                510  ...
# 59               370                335                300  ...
# 66               390                385                345  ...
# 68               490                395                450  ...
# 78               175                160                330  ...
# 111              400                355                415  ...
#
#      Pop 55 - 59 years  Pop 60 - 64 years  Pop 65 - 69 years  \
# 76                2560               2120               1760
# 136               3490               2755               2220
# 50                2985               2475               2080
# 130               3555               3135               2590
# 116               3120               2810               2575
# 13                2920               2480               2050
# 131               2980               2555               2255
# 92                2200               1735               1375
# 25                2505               1875               1520
# 44                2410               1855               1530
# 16                2495               2125               1785
# 0                 2195               1795               1595
# 1                 1955               1520               1285
# 74                1800               1435               1120
# 81                1065                820                635
# 94                1780               1700               1725
# 24                2050               1555               1375
# 126               1935               1600               1450
# 103               1610               1420               1295
# 128               2230               2000               1905
# 118               2185               1755               1310
# 69                1725               1395               1175
# 41                1935               1620               1670
# 26                1740               1225               1040
# 117               1875               1635               1430
# 135               2080               1705               1350
# 46                1695               1450               1395
# 119               1890               1470               1150
# 129               2040               1990               1670
# 34                1865               1635               1465
# ..                 ...                ...                ...
# 56                 755                680                620
# 17                 840                740                520
# 90                 815                600                470
# 109                815                620                555
# 9                 1045                810                630
# 95                 700                765                830
# 7                  790                720                580
# 71                 635                465                320
# 100                755                775                750
# 22                 805                585                420
# 11                 930                805                670
# 3                  870                650                520
# 2                  660                535                490
# 28                 710                495                420
# 18                 840                680                535
# 88                 680                535                455
# 108                765                585                420
# 27                 625                490                390
# 139                800                755                590
# 65                 635                560                500
# 4                  730                525                415
# 14                 700                645                605
# 40                 800                725                575
# 57                 710                570                520
# 113                565                485                365
# 59                 615                535                395
# 66                 525                445                405
# 68                 565                375                325
# 78                 320                330                305
# 111                465                420                275
#
#      Pop 70 - 74 years  Pop 75 - 79 years  Pop 80 - 84 years  \
# 76                1225                740                530
# 136               1810               1550               1330
# 50                1445               1130                780
# 130               1670               1005                680
# 116               1855               1770               1440
# 13                1545               1240               1080
# 131               1535               1045                590
# 92                1045                890                640
# 25                1105               1085                950
# 44                1200                950                800
# 16                1285                930                605
# 0                 1185                885                700
# 1                  885                630                465
# 74                 750                530                365
# 81                 380                240                135
# 94                1335               1030                750
# 24                1060               1035                850
# 126               1070                975                855
# 103               1000                775                590
# 128               1290               1065                865
# 118                955                850                700
# 69                 695                515                430
# 41                1360               1235               1085
# 26                 775                725                585
# 117               1215               1200               1090
# 135                975                775                520
# 46                1035                920                695
# 119                740                565                520
# 129               1010                835                750
# 34                 920               1020                715
# ..                 ...                ...                ...
# 56                 425                310                235
# 17                 350                300                205
# 90                 310                215                180
# 109                390                310                300
# 9                  435                335                315
# 95                 665                470                305
# 7                  485                495                530
# 71                 190                105                 65
# 100                525                385                275
# 22                 315                360                270
# 11                 550                475                465
# 3                  350                295                270
# 2                  375                335                320
# 28                 385                440                395
# 18                 340                225                165
# 88                 270                175                150
# 108                320                240                175
# 27                 370                375                365
# 139                510                510                490
# 65                 365                250                200
# 4                  305                235                180
# 14                 465                325                290
# 40                 430                315                225
# 57                 305                260                210
# 113                240                165                115
# 59                 235                215                130
# 66                 260                210                145
# 68                 200                155                100
# 78                 260                220                220
# 111                235                160                155
#
#      Pop 85 - 89 years  Pop 90 - 94 years  Pop 95 - 99 years  \
# 76                 365                 90                 20
# 136               1130                305                 60
# 50                 830                230                 40
# 130                685                205                 65
# 116               1345                370                 70
# 13                1480                450                115
# 131                445                110                 30
# 92                 595                170                 30
# 25                 870                210                 35
# 44                 775                185                 40
# 16                 565                150                 25
# 0                  615                160                 50
# 1                  300                 70                 10
# 74                 250                 65                  5
# 81                  95                 20                  5
# 94                1040                340                110
# 24                 700                170                 30
# 126                900                240                 65
# 103                940                325                100
# 128                925                270                 90
# 118                905                260                 60
# 69                 520                130                 50
# 41                1640                520                125
# 26                 400                 95                 10
# 117               1220                385                 90
# 135                625                210                 60
# 46                 665                170                 55
# 119                660                225                 45
# 129                880                245                 90
# 34                1000                315                 75
# ..                 ...                ...                ...
# 56                 255                 70                 10
# 17                 140                 45                 15
# 90                 150                 45                  5
# 109                230                 55                 10
# 9                  325                115                 10
# 95                 395                100                 35
# 7                  950                375                 70
# 71                  50                 10                 10
# 100                325                 80                 25
# 22                 205                 50                  5
# 11                 535                160                 20
# 3                  300                 85                 15
# 2                  350                100                 20
# 28                 380                115                 10
# 18                 140                 35                  5
# 88                 195                 65                 15
# 108                165                 45                 10
# 27                 365                105                 25
# 139                540                165                 30
# 65                 195                 60                 15
# 4                  145                 40                  5
# 14                 325                130                 25
# 40                 245                 60                 15
# 57                 230                 75                 10
# 113                140                 55                  5
# 59                 125                 35                  5
# 66                 195                 60                 20
# 68                 115                 20                 10
# 78                 305                100                 40
# 111                145                 75                  0
#
#      Pop 100 years and over
# 76                        5
# 136                       5
# 50                        5
# 130                      10
# 116                      10
# 13                       30
# 131                       0
# 92                        0
# 25                        0
# 44                       10
# 16                        0
# 0                         5
# 1                         0
# 74                        0
# 81                        0
# 94                       20
# 24                        0
# 126                      10
# 103                      30
# 128                      10
# 118                       5
# 69                       10
# 41                       30
# 26                        0
# 117                      10
# 135                       5
# 46                       15
# 119                      10
# 129                      15
# 34                       15
# ..                      ...
# 56                        0
# 17                        5
# 90                        0
# 109                       0
# 9                         0
# 95                        0
# 7                        15
# 71                        0
# 100                       0
# 22                        0
# 11                        5
# 3                         0
# 2                         5
# 28                        0
# 18                        0
# 88                        0
# 108                       0
# 27                        5
# 139                       5
# 65                        0
# 4                         0
# 14                       10
# 40                        0
# 57                        0
# 113                       0
# 59                        0
# 66                        5
# 68                        0
# 78                       10
# 111                       0
#
# [140 rows x 27 columns]

# %%
df_wellbeing.rename(columns = {'   In Labour Force':'In Labour Force'}, inplace = True)
